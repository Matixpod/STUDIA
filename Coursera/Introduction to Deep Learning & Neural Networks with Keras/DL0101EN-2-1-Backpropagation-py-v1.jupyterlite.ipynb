# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # BackPropagation
#
# Estimated time needed: **30** mins

# %% [markdown]
# Backpropagation is the key algorithm used for training neural networks, allowing them to learn from data. It is based on the gradient descent optimization technique and works by iteratively adjusting the weights and biases of the network to minimize the error between the predicted and actual outputs.
#  In this lab, we will create a neural network to implement backpropagation for a XOR problem.

# %% [markdown]
# # Objective for this notebook
#
# * Train a Neural Network to Solve the XOR Problem
# * Implement Backpropagation for Neural Network Training
# * Demonstrate the Use of Activation Functions
# * Understand the Learning Process Over Multiple Epochs
# * Demonstrate Weight and Bias Adjustments via Gradient Descent
# * Evaluate the Model's Performance After Training
# * Monitor and Analyze the Training Process

# %% [markdown]
# <h2>Table of Contents</h2>
#
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 4>
# 1. <a href="#Import-Required-Libraries">Import Required Libraries</a><br>
# 2. <a href="#Initialize-Inputs">Initialize Inputs</a><br>
# 3. <a href="#Declare-the-network-parameters">Declare the network parameters</a><br>
# 4. <a href="#Define-the-weights">Define the weights</a><br>
# 5. <a href="#Training-the-Neural-Network">Training the Neural Network</a><br>
# 6. <a href="#Testing-the-Network">Testing the Network</a><br>
# 7. <a href="#Plot-the-error">Plot the error</a><br>
#
# </font>
# </div>

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented. 
# If you run this notebook on a different environment, e.g., your desktop, you may need to uncomment and install certain libraries.

#!pip install numpy==1.26.4
#!pip install matplotlib==3.5.2

# %% [markdown]
# ## Import Required Libraries

# %%
# Importing the required library
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Initialize Inputs
# Define the input and expected output for a XOR gate problem

# %%
# Defining inputs and expected output (XOR truth table)
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
d = np.array([0, 1, 1, 0])  # Expected output for XOR

# %% [markdown]
# # Declare the network parameters
#
# Define the network parameters such as
# 1. number of input neurons
# 2. hidden layer neurons
# 3. output neurons
# 4. learning rate
# 5. number of epochs

# %%
# Network parameters
inputSize = 2     # Number of input neurons (x1, x2)
hiddenSize = 2    # Number of hidden neurons
outputSize = 1    # Number of output neurons
lr = 0.1          # Learning rate
epochs = 180000   # Number of training epochs

# %% [markdown]
# ## Define the weights
# Declare the weights for the neurons. The initial weights are taken as random numbers which are then optimized by the backpropagation algorithm

# %%
# Initialize weights and biases randomly within the range [-1, 1]
w1 = np.random.rand(hiddenSize, inputSize) * 2 - 1  # Weights from input to hidden layer
b1 = np.random.rand(hiddenSize, 1) * 2 - 1         # Bias for hidden layer
w2 = np.random.rand(outputSize, hiddenSize) * 2 - 1  # Weights from hidden to output layer
b2 = np.random.rand(outputSize, 1) * 2 - 1         # Bias for output layer
# Out:
# [[-0.63626836 -0.83380607]
#  [-0.136334    0.97755195]]
# [[0.96529555]
#  [0.86654533]]
#
# [[0.83522978 0.76891159]]
# [[0.98144399]]

# %% [markdown]
# ## Training the Neural Network
#
# The neural network works in 5 stages:
# 1. Forward pass
#     * The input **X** is multiplied by the weights **w1** and passed through the first layer, followed by the application of the sigmoid or ReLU activation function. This gives the output for the hidden layer.
#     * The output of the hidden layer is then passed through the second set of weights **w2** to compute the final output. Again, a sigmoid activation function is used to generate the final output **a2**.
#
# 2. Error calculation
#     * The error is computed as the difference between the expected output **(d)** and the actual output **(a2)**.
# 3. Backward pass
#     * **Output Layer**: The derivative of the sigmoid activation function is applied to the error, producing the gradient for the output layer **(da2)**. This is used to calculate how much the weights in the output layer need to be adjusted.
#     * **Hidden Layer**: The error is then propagated backward to the hidden layer. The gradient at the hidden layer **(da1)** is computed by taking the dot product of the transpose of the weights **(w2.T)** and the gradient from the output layer. The derivative of the activation function (sigmoid or ReLU) is used to adjust this error.
# 4. Weights and bias updates
#     * After computing the **gradients (dz1, dz2)**, the **weights (w1, w2)** and **biases (b1, b2)** are updated using the **learning rate (lr)** and **the gradients**. The updates are done to minimize the error and improve the model’s predictions.
# 5. Training:
#     * This entire process is repeated over many iterations **(epochs)**. During each epoch, the model adjusts its weights and biases to reduce the error. Over time, the network learns to approximate the XOR function.
# Forward Pass:

# %%
# Training the network using backpropagation
error_list = []
for epoch in range(epochs):
    # Forward pass
    z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
    a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

    z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
    a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

    # Error calculation and backpropagation
    error = d - a2  # Difference between expected and actual output
    da2 = error * (a2 * (1 - a2))  # Derivative for output layer
    dz2 = da2  # Gradient for output layer

    # Propagate error to hidden layer
    da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
    dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer

    # Update weights and biases
    w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
    b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer

    w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
    b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
    if (epoch+1)%10000 == 0:
        print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
        error_list.append(np.average(abs(error)))
# Out:
# Epoch: 9999, Average error: 0.26060
# Epoch: 19999, Average error: 0.25790
# Epoch: 29999, Average error: 0.25688
# Epoch: 39999, Average error: 0.25635
# Epoch: 49999, Average error: 0.25603
# Epoch: 59999, Average error: 0.25585
# Epoch: 69999, Average error: 0.25575
# Epoch: 79999, Average error: 0.25573
# Epoch: 89999, Average error: 0.25576
# Epoch: 99999, Average error: 0.25585
# Epoch: 109999, Average error: 0.25602
# Epoch: 119999, Average error: 0.25626
# Epoch: 129999, Average error: 0.25662
# Epoch: 139999, Average error: 0.25715
# Epoch: 149999, Average error: 0.25796
# Epoch: 159999, Average error: 0.25931
# Epoch: 169999, Average error: 0.26195
# Epoch: 179999, Average error: 0.26981
# Epoch: 189999, Average error: 0.34349
# Epoch: 199999, Average error: 0.33828
# Epoch: 209999, Average error: 0.33832
# Epoch: 219999, Average error: 0.33965
# Epoch: 229999, Average error: 0.34092
# Epoch: 239999, Average error: 0.34162
# Epoch: 249999, Average error: 0.34183
# Epoch: 259999, Average error: 0.34178
# Epoch: 269999, Average error: 0.34161
# Epoch: 279999, Average error: 0.34141
# Epoch: 289999, Average error: 0.34121
# Epoch: 299999, Average error: 0.34100
# Epoch: 309999, Average error: 0.34081
# Epoch: 319999, Average error: 0.34063
# Epoch: 329999, Average error: 0.34046
# Epoch: 339999, Average error: 0.34030
# Epoch: 349999, Average error: 0.34014
# Epoch: 359999, Average error: 0.34000
# Epoch: 369999, Average error: 0.33987
# Epoch: 379999, Average error: 0.33974
# Epoch: 389999, Average error: 0.33962
# Epoch: 399999, Average error: 0.33950
# Epoch: 409999, Average error: 0.33939
# Epoch: 419999, Average error: 0.33928
# Epoch: 429999, Average error: 0.33918
# Epoch: 439999, Average error: 0.33909
# Epoch: 449999, Average error: 0.33900
# Epoch: 459999, Average error: 0.33891
# Epoch: 469999, Average error: 0.33882
# Epoch: 479999, Average error: 0.33874
# Epoch: 489999, Average error: 0.33866
# Epoch: 499999, Average error: 0.33859
# Epoch: 509999, Average error: 0.33852
# Epoch: 519999, Average error: 0.33845
# Epoch: 529999, Average error: 0.33838
# Epoch: 539999, Average error: 0.33832
# Epoch: 549999, Average error: 0.33825
# Epoch: 559999, Average error: 0.33819
# Epoch: 569999, Average error: 0.33814
# Epoch: 579999, Average error: 0.33808
# Epoch: 589999, Average error: 0.33802
# Epoch: 599999, Average error: 0.33797
# Epoch: 609999, Average error: 0.33792
# Epoch: 619999, Average error: 0.33787
# Epoch: 629999, Average error: 0.33782
# Epoch: 639999, Average error: 0.33777
# Epoch: 649999, Average error: 0.33773
# Epoch: 659999, Average error: 0.33768
# Epoch: 669999, Average error: 0.33764
# Epoch: 679999, Average error: 0.33760
# Epoch: 689999, Average error: 0.33756
# Epoch: 699999, Average error: 0.33752
# Epoch: 709999, Average error: 0.33748
# Epoch: 719999, Average error: 0.33744
# Epoch: 729999, Average error: 0.33740
# Epoch: 739999, Average error: 0.33737
# Epoch: 749999, Average error: 0.33733
# Epoch: 759999, Average error: 0.33730
# Epoch: 769999, Average error: 0.33726
# Epoch: 779999, Average error: 0.33723
# Epoch: 789999, Average error: 0.33720
# Epoch: 799999, Average error: 0.33717
# Epoch: 809999, Average error: 0.33714
# Epoch: 819999, Average error: 0.33711
# Epoch: 829999, Average error: 0.33708
# Epoch: 839999, Average error: 0.33705
# Epoch: 849999, Average error: 0.33702
# Epoch: 859999, Average error: 0.33699
# Epoch: 869999, Average error: 0.33697
# Epoch: 879999, Average error: 0.33694
# Epoch: 889999, Average error: 0.33691
# Epoch: 899999, Average error: 0.33689
# Epoch: 909999, Average error: 0.33686
# Epoch: 919999, Average error: 0.33684
# Epoch: 929999, Average error: 0.33682
# Epoch: 939999, Average error: 0.33679
# Epoch: 949999, Average error: 0.33677
# Epoch: 959999, Average error: 0.33675
# Epoch: 969999, Average error: 0.33672
# Epoch: 979999, Average error: 0.33670
# Epoch: 989999, Average error: 0.33668
# Epoch: 999999, Average error: 0.33666

# %% [markdown]
# ## Testing the Network
# After training, you can now test the neural network to verify that it has learned the XOR function and outputs the correct values close to [0, 1, 1, 0]

# %%
# Testing the trained network
z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

# Print results
print('Final output after training:', a2)
print('Ground truth', d)
print('Error after training:', error)
print('Average error: %0.05f'%np.average(abs(error)))
# Out:
# Final output after training: [[0.00783916 0.99185779 0.99186976 0.00997165]]
# Ground truth [0 1 1 0]
# Error after training: [[-0.00783918  0.00814223  0.00813027 -0.00997168]]
# Average error: 0.00852

# %% [markdown]
# ## Plot the error
# Here, we plot the error as a function of epochs. This shows how error changed over multiple iterations of forward and backward passes and how the network learnt over time

# %%
# Plot error
plt.plot(error_list)
plt.title('Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# # Practice exercise 1

# %% [markdown]
# Implement backpropagation for **AND problem** using similar input as used for XOR problem above and plot the error

# %%
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T# 2x4 matrix, each column is a training example
d = np.array([0, 0, 0, 1])  # Expected output for AND

inputSize = 2
hiddenSize = 2
outputSize = 1
lr = 0.1
epochs = 180000

w1 = np.random.rand(hiddenSize,inputSize) * 2 - 1
b1 = np.random.rand(hiddenSize,1) * 2 - 1
w2 = np.random.rand(outputSize,hiddenSize) * 2 - 1
b2 = np.random.rand(outputSize,1) * 2 - 1


error_list = []


for epoch in range(epochs):
    z1 = np.dot(w1,X) + b1
    a1 = 1.0 / (1.0 + np.exp(-z1))

    z2 = np.dot(w2,a1) + b2
    a2 = 1.0 / (1.0 + np.exp(-z2))
    
    
    derror = -(d - a2)
    da2 = a2 * (1 - a2)
    dea2 = da2 * derror
    grad_w2 = np.dot(dea2, a1.T)

    
    da1_error = np.dot(w2.T, dea2) 
    da1 = a1 * (1 - a1)
    dea1 = da1_error * da1 
    grad_w1 = np.dot(dea1, X.T)  
    
    w2 = w2 - lr * grad_w2
    w1 = w1 - lr * grad_w1
    
    b2 = b2 - lr * np.sum(dea2, axis=1, keepdims=True)
    b1 = b1 - lr * np.sum(dea1, axis=1, keepdims=True)

    if (epoch+1)%10000 == 0:
        print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(derror))))
        error_list.append(np.average(abs(derror)))

    
    
plt.plot(error_list)
plt.title('Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()

np.set_printoptions(suppress=True, precision=4)
print('Final output after training:', np.round(a2,5))
print('Ground truth', d)
print('Error after training:', derror)
print('Average error: %0.05f'%np.average(abs(derror)))
# Out:
# Epoch: 9999, Average error: 0.02209
# Epoch: 19999, Average error: 0.01407
# Epoch: 29999, Average error: 0.01100
# Epoch: 39999, Average error: 0.00929
# Epoch: 49999, Average error: 0.00817
# Epoch: 59999, Average error: 0.00736
# Epoch: 69999, Average error: 0.00675
# Epoch: 79999, Average error: 0.00626
# Epoch: 89999, Average error: 0.00586
# Epoch: 99999, Average error: 0.00553
# Epoch: 109999, Average error: 0.00525
# Epoch: 119999, Average error: 0.00500
# Epoch: 129999, Average error: 0.00479
# Epoch: 139999, Average error: 0.00460
# Epoch: 149999, Average error: 0.00443
# Epoch: 159999, Average error: 0.00427
# Epoch: 169999, Average error: 0.00413
# Epoch: 179999, Average error: 0.00401
# Final output after training: [[0.0002 0.0046 0.0046 0.9933]]
# Ground truth [0 0 0 1]
# Error after training: [[ 0.0002  0.0046  0.0046 -0.0067]]
# Average error: 0.00401

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
#
#
# X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
# d = np.array([0, 0, 0, 1])  # Expected output for AND
#
# # Training the network using backpropagation
# error_list = []
# for epoch in range(epochs):
#     # Forward pass
#     z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
#     a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
#     z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
#     a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
#     # Error calculation and backpropagation
#     error = d - a2  # Difference between expected and actual output
#     da2 = error * (a2 * (1 - a2))  # Derivative for output layer
#     dz2 = da2  # Gradient for output layer
#
#     # Propagate error to hidden layer
#     da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
#     dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer
#
#     # Update weights and biases
#     w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
#     b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer
#
#     w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
#     b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
#     if (epoch+1)%10000 == 0:
#         print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
#         error_list.append(np.average(abs(error)))
#
#
# # Testing the trained network
# z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
# a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
# z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
# a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
# # Print results
# print('\nFinal output after training:', a2)
# print('Ground truth', d)
# print('Error after training:', error)
# print('Average error: %0.05f'%np.average(abs(error)))
#
# # Plot error
# plt.plot(error_list)
# plt.title('Error')
# plt.xlabel('Epochs')
# plt.ylabel('Error')
# plt.show()
#
#
# -->

# %% [markdown]
# # Practice exercise 2

# %% [markdown]
# Now, decrease the learning rate to 0.01 and increase the number of epochs to 1000000 and check the error for XOR gate

# %%
lr = 0.1         # Learning rate
epochs = 1000000   # Number of training epochs


# Defining inputs and expected output (XOR truth table)
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
d = np.array([0, 1, 1, 0])  # Expected output for XOR


# Training the network using backpropagation
error_list = []
for epoch in range(epochs):
    # Forward pass
    z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
    a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

    z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
    a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

    # Error calculation and backpropagation
    error = d - a2  # Difference between expected and actual output
    da2 = error * (a2 * (1 - a2))  # Derivative for output layer
    dz2 = da2  # Gradient for output layer

    # Propagate error to hidden layer
    da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
    dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer

    # Update weights and biases
    w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
    b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer

    w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
    b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
    if (epoch+1)%10000 == 0:
        print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
        error_list.append(np.average(abs(error)))


# Testing the trained network
z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

# Print results
print('\nFinal output after training:', a2)
print('Ground truth', d)
print('Error after training:', error)
print('Average error: %0.05f'%np.average(abs(error)))


# Plot error
plt.plot(error_list)
plt.title('Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()
# Out:
# Epoch: 9999, Average error: 0.33545
# Epoch: 19999, Average error: 0.33540
# Epoch: 29999, Average error: 0.33534
# Epoch: 39999, Average error: 0.33529
# Epoch: 49999, Average error: 0.33525
# Epoch: 59999, Average error: 0.33520
# Epoch: 69999, Average error: 0.33516
# Epoch: 79999, Average error: 0.33513
# Epoch: 89999, Average error: 0.33509
# Epoch: 99999, Average error: 0.33506
# Epoch: 109999, Average error: 0.33502
# Epoch: 119999, Average error: 0.33499
# Epoch: 129999, Average error: 0.33496
# Epoch: 139999, Average error: 0.33494
# Epoch: 149999, Average error: 0.33491
# Epoch: 159999, Average error: 0.33489
# Epoch: 169999, Average error: 0.33486
# Epoch: 179999, Average error: 0.33484
# Epoch: 189999, Average error: 0.33482
# Epoch: 199999, Average error: 0.33480
# Epoch: 209999, Average error: 0.33477
# Epoch: 219999, Average error: 0.33476
# Epoch: 229999, Average error: 0.33474
# Epoch: 239999, Average error: 0.33472
# Epoch: 249999, Average error: 0.33470
# Epoch: 259999, Average error: 0.33468
# Epoch: 269999, Average error: 0.33467
# Epoch: 279999, Average error: 0.33465
# Epoch: 289999, Average error: 0.33464
# Epoch: 299999, Average error: 0.33462
# Epoch: 309999, Average error: 0.33461
# Epoch: 319999, Average error: 0.33459
# Epoch: 329999, Average error: 0.33458
# Epoch: 339999, Average error: 0.33457
# Epoch: 349999, Average error: 0.33456
# Epoch: 359999, Average error: 0.33454
# Epoch: 369999, Average error: 0.33453
# Epoch: 379999, Average error: 0.33452
# Epoch: 389999, Average error: 0.33451
# Epoch: 399999, Average error: 0.33450
# Epoch: 409999, Average error: 0.33449
# Epoch: 419999, Average error: 0.33448
# Epoch: 429999, Average error: 0.33447
# Epoch: 439999, Average error: 0.33446
# Epoch: 449999, Average error: 0.33445
# Epoch: 459999, Average error: 0.33444
# Epoch: 469999, Average error: 0.33443
# Epoch: 479999, Average error: 0.33442
# Epoch: 489999, Average error: 0.33441
# Epoch: 499999, Average error: 0.33440
# Epoch: 509999, Average error: 0.33439
# Epoch: 519999, Average error: 0.33439
# Epoch: 529999, Average error: 0.33438
# Epoch: 539999, Average error: 0.33437
# Epoch: 549999, Average error: 0.33436
# Epoch: 559999, Average error: 0.33435
# Epoch: 569999, Average error: 0.33435
# Epoch: 579999, Average error: 0.33434
# Epoch: 589999, Average error: 0.33433
# Epoch: 599999, Average error: 0.33433
# Epoch: 609999, Average error: 0.33432
# Epoch: 619999, Average error: 0.33431
# Epoch: 629999, Average error: 0.33431
# Epoch: 639999, Average error: 0.33430
# Epoch: 649999, Average error: 0.33429
# Epoch: 659999, Average error: 0.33429
# Epoch: 669999, Average error: 0.33428
# Epoch: 679999, Average error: 0.33428
# Epoch: 689999, Average error: 0.33427
# Epoch: 699999, Average error: 0.33426
# Epoch: 709999, Average error: 0.33426
# Epoch: 719999, Average error: 0.33425
# Epoch: 729999, Average error: 0.33425
# Epoch: 739999, Average error: 0.33424
# Epoch: 749999, Average error: 0.33424
# Epoch: 759999, Average error: 0.33423
# Epoch: 769999, Average error: 0.33423
# Epoch: 779999, Average error: 0.33422
# Epoch: 789999, Average error: 0.33422
# Epoch: 799999, Average error: 0.33421
# Epoch: 809999, Average error: 0.33421
# Epoch: 819999, Average error: 0.33420
# Epoch: 829999, Average error: 0.33420
# Epoch: 839999, Average error: 0.33419
# Epoch: 849999, Average error: 0.33419
# Epoch: 859999, Average error: 0.33418
# Epoch: 869999, Average error: 0.33418
# Epoch: 879999, Average error: 0.33418
# Epoch: 889999, Average error: 0.33417
# Epoch: 899999, Average error: 0.33417
# Epoch: 909999, Average error: 0.33416
# Epoch: 919999, Average error: 0.33416
# Epoch: 929999, Average error: 0.33416
# Epoch: 939999, Average error: 0.33415
# Epoch: 949999, Average error: 0.33415
# Epoch: 959999, Average error: 0.33414
# Epoch: 969999, Average error: 0.33414
# Epoch: 979999, Average error: 0.33414
# Epoch: 989999, Average error: 0.33413
# Epoch: 999999, Average error: 0.33413
#
# Final output after training: [[0.00312777 0.66665009 0.66665012 0.66668872]]
# Ground truth [0 1 1 0]
# Error after training: [[-0.00312777  0.33334991  0.33334988 -0.66668872]]
# Average error: 0.33413

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
#
# lr = 0.01         # Learning rate
# epochs = 1000000   # Number of training epochs
#
#
# # Defining inputs and expected output (XOR truth table)
# X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
# d = np.array([0, 1, 1, 0])  # Expected output for XOR
#
#
# # Training the network using backpropagation
# error_list = []
# for epoch in range(epochs):
#     # Forward pass
#     z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
#     a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
#     z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
#     a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
#     # Error calculation and backpropagation
#     error = d - a2  # Difference between expected and actual output
#     da2 = error * (a2 * (1 - a2))  # Derivative for output layer
#     dz2 = da2  # Gradient for output layer
#
#     # Propagate error to hidden layer
#     da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
#     dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer
#
#     # Update weights and biases
#     w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
#     b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer
#
#     w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
#     b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
#     if (epoch+1)%10000 == 0:
#         print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
#         error_list.append(np.average(abs(error)))
#
#
# # Testing the trained network
# z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
# a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
# z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
# a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
# # Print results
# print('\nFinal output after training:', a2)
# print('Ground truth', d)
# print('Error after training:', error)
# print('Average error: %0.05f'%np.average(abs(error)))
#
#
# # Plot error
# plt.plot(error_list)
# plt.title('Error')
# plt.xlabel('Epochs')
# plt.ylabel('Error')
# plt.show()
#
#
# -->

# %% [markdown]
# ## Thank you for completing this lab!
#
# This notebook was created by [Aman Aggarwal](https://www.linkedin.com/in/aggarwal-aman/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 1.0  | Aman  |  Created the lab |
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
