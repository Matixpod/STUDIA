# %% [markdown]
# Mateusz Podporski nr. 152774

# %% [markdown]
# Problem sterowanie ogrzewaniem domu
#
# Zmienne wejściowe:
# - temp pomieszczenia (bardzo niska, niska, optymalna, wysoka)
# - temp zewnetrzna (bardzo niska, niska, średnia, wysoka, bardzo wysoka)
#
# Zmienna wyjściowa:
# - Intensywność grzania (bardzo niskie 0010, niskie, średnie, wysokie)
