# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = np.array([5, 3, np.nan, 4, np.nan])
b = np.array([4, np.nan, 2, 5, np.nan])



def cosine_similarity_nan(a,b):
    mask = ~np.isnan(a) & ~np.isnan(b)
    if not np.any(mask):
        return np.nan
    a = a[mask]
    b = b[mask]
    norm_a = np.linalg.norm(a)
    norm_b = np.linalg.norm(b)
    if norm_a == 0 or norm_b == 0:
        return 0
    if norm_a == norm_b:
        return 1.0
    dot_ab = a @ b
    if dot_ab == 0:
        return 0.0
    return dot_ab / (norm_a * norm_b)
print(cosine_similarity_nan(a,b))
# Out:
# 1.0

# %%
jan = np.array([5,3,np.nan,np.nan])
anna = np.array([4,3,5,2])
piotr = np.array([5,3,4,1])

print(cosine_similarity_nan(anna,piotr))
# Out:
# 0.9718253158075499

# %%
def user_based_colaborative_filtering(ratings_matrix, target_user):
    sim_table = {}
    for other_user in ratings_matrix:
        sim_table
